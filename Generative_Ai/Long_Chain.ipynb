# %%
# import the request library
import requests
API_KEY = "link"
CITY = f"http:/khsdfhsghdfkjghfdkjghkfdjgkfdhgkjdf{CITY}JKDSFHK{API_KEY}"
response = requests.get(URL)
data = response.json()
Print(f"Lahore ka temperature {data['main']['temp']} Kelvin")

# %% [markdown]
# # LongChain

# %%
import os

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   2.4.0
# annotated-types           0.6.0
# anyio                     4.10.0
# asttokens                 3.0.1
# astunparse                1.6.3
# async-timeout             4.0.3
# attrs                     25.4.0
# Bottleneck                1.4.2
# brotlicffi                1.2.0.0
# catboost                  1.2.10
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# choreographer             1.2.1
# click                     8.2.1
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.1
# cycler                    0.11.0
# dacite                    1.8.1
# debugpy                   1.8.18
# decorator                 5.2.1
# distro                    1.9.0
# et_xmlfile                2.0.0
# exceptiongroup            1.3.1
# executing                 2.2.1
# ...

# %%
# !pip install langchain-openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.1 MB 236.2 kB/s eta 0:00:03
#    ------------------ --------------------- 0.5/1.1 MB 236.2 kB/s eta 0:00:03
#    ------------------ --------------------- 0.5/1.1 MB 236.2 kB/s eta 0:00:03
# ...

# %%
from langchain_openai import OpenAI
os.environ['OPENAI_API_KEY'] = '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'
openai = OpenAI(temperature=0.9)
text = "What is the capital of Pakistan?"
print(openai(text))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[15], line 5
#       3 openai = OpenAI(temperature=0.9)
#       4 text = "What is the capital of Pakistan?"
# ----> 5 print(openai.invoke(text))
#
# File c:\Users\Muhammad Asim\miniconda3\envs\ml_python\lib\site-packages\langchain_core\language_models\llms.py:380, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     369 @override
#     370 def invoke(
#     371     self,
#    (...)
#     376     **kwargs: Any,
#     377 ) -> str:
#     378     config = ensure_config(config)
#     379     return (
# --> 380         self.generate_prompt(
#     381             [self._convert_input(input)],
#     382             stop=stop,
#     383             callbacks=config.get("callbacks"),
#     384             tags=config.get("tags"),
#     385             metadata=config.get("metadata"),
# ...

# %% [markdown]
# # Huggingface

# %%
from laingchain import HuggingFaceHub
import os 
os.environ['HF_HOME'] = '/content'
llm = HuggingFaceHub(repo_id="google/flan-t5-xxl", model_kwargs={"temperature":0.9}, "max_length":512)
llm("What is the capital of Pakistan?")
# Out:
#   Cell In[16], line 2
#     llm = HuggingFaceHub(repo_id="google/flan-t5-xxl", model_kwargs={"temperature":0.9}, "max_length":512)
#                                                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
# !pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.1 MB 322.4 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/9.1 MB 322.4 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/9.1 MB 322.4 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/9.1 MB 322.4 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/9.1 MB 322.4 kB/s eta 0:00:27
# ...
