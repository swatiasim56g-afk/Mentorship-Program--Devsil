# %% [markdown]
# <div style="background: linear-gradient(90deg,#1f4e79,#4CAF50); padding:20px; border-radius:10px;">
# <h1 style="color:white; text-align:center;">Programming for Artificial Intelligence</h1>
# <h2 style="color:white; text-align:center;">Lab Task 2 Solution</h2>
# <p style="color:white; text-align:center;">Variables, Data Types, Expressions and Real-World Reasoning</p>
# </div>

# %% [markdown]
# <div style="background-color:#1f77b4; padding:15px; border-radius:8px;">
# <h2 style="color:white;">Part A – Basic Programming Tasks</h2>
# </div>

# %% [markdown]
# <div style="background-color:#e8f4ff; padding:12px; border-left:6px solid #1f77b4; border-radius:6px;">
# <h3>Task 1 – Student Information</h3>
# </div>

# %%
# Task 1

name = "Muhammad Asim"
age = 22
university = "Your University Name"
department = "Artificial Intelligence"

print("My name is", name)
print("I am", age, "years old.")
print("I study at", university, "in the", department, "department.")
# Out:
# My name is Muhammad Asim
# I am 22 years old.
# I study at Your University Name in the Artificial Intelligence department.

# %% [markdown]
# <div style="background-color:#e8f4ff; padding:12px; border-left:6px solid #1f77b4; border-radius:6px;">
# <h3>Task 2 – Grocery Bill Calculation</h3>
# </div>

# %%
# Task 2

item1 = 120
item2 = 250
item3 = 80

total_bill = item1 + item2 + item3

print("Price of Item 1:", item1)
print("Price of Item 2:", item2)
print("Price of Item 3:", item3)

print("Total Bill =", total_bill)

# %% [markdown]
# <div style="background-color:#e8f4ff; padding:12px; border-left:6px solid #1f77b4; border-radius:6px;">
# <h3>Task 3 – Celsius to Fahrenheit Conversion</h3>
# </div>

# %%
# Task 3

celsius = 30

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Celsius:", celsius)
print("Temperature in Fahrenheit:", fahrenheit)

# %% [markdown]
# <div style="background-color:#e8f4ff; padding:12px; border-left:6px solid #1f77b4; border-radius:6px;">
# <h3>Task 4 – Basic Calculator</h3>
# </div>

# %%
# Task 4

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum =", num1 + num2)
print("Difference =", num1 - num2)
print("Multiplication =", num1 * num2)
print("Division =", num1 / num2)

# %% [markdown]
# <div style="background-color:#e8f4ff; padding:12px; border-left:6px solid #1f77b4; border-radius:6px;">
# <h3>Task 5 – Rectangle Area and Perimeter</h3>
# </div>

# %%
# Task 5

length = 10
width = 5

area = length * width
perimeter = 2 * (length + width)

print("Length:", length)
print("Width:", width)

print("Area of rectangle:", area)
print("Perimeter of rectangle:", perimeter)

# %% [markdown]
# <div style="background-color:#28a745; padding:15px; border-radius:8px;">
# <h2 style="color:white;">Part B – Data Type Exploration</h2>
# </div>

# %% [markdown]
# <div style="background-color:#e9f9ee; padding:12px; border-left:6px solid #28a745; border-radius:6px;">
# <h3>Task B1 – Data Types in Python</h3>
# </div>

# %%
# Task B1

integer_value = 10
float_value = 5.5
string_value = "Artificial Intelligence"
boolean_value = True

print(integer_value, type(integer_value))
print(float_value, type(float_value))
print(string_value, type(string_value))
print(boolean_value, type(boolean_value))

# %% [markdown]
# <div style="background-color:#e9f9ee; padding:12px; border-left:6px solid #28a745; border-radius:6px;">
# <h3>Task B2 – Type Casting</h3>
# </div>

# %%
# Task B2

number_string = "25"

number_integer = int(number_string)

print("Original value:", number_string)
print("Converted value:", number_integer)
print("Data type:", type(number_integer))

# %% [markdown]
# <div style="background-color:#e9f9ee; padding:12px; border-left:6px solid #28a745; border-radius:6px;">
# <h3>Task B3 – Tuple Unpacking</h3>
# </div>

# %%
# Task B3

coordinates = (10, 20)

x, y = coordinates

print("X coordinate:", x)
print("Y coordinate:", y)

# %% [markdown]
# <div style="background-color:#6f42c1; padding:15px; border-radius:8px;">
# <h2 style="color:white;">Part C – Conceptual and Real-World Thinking</h2>
# </div>

# %% [markdown]
# <div style="background-color:#f3ecff; padding:12px; border-left:6px solid #6f42c1; border-radius:6px;">
# <h3>Conceptual Task</h3>
# </div>

# %% [markdown]
# # Conceptual Task 1

# %%
# Classroom variables example

number_of_students = 35
room_temperature = 24
available_computers = 20

print("Number of students:", number_of_students)
print("Room temperature:", room_temperature)
print("Available computers:", available_computers)

# %% [markdown]
# # Conceptual Task 2
#
# Daily decision using variables

# %%
# Transportation decision example

distance = 10      # distance to university in km
bus_cost = 50
bike_cost = 0

print("Distance to university:", distance, "km")
print("Bus cost:", bus_cost)
print("Bike cost:", bike_cost)

if bus_cost < bike_cost:
    print("Bus is cheaper")
else:
    print("Bike is cheaper")

# %% [markdown]
# # Conceptual Task 3
#
# Information a computer cannot know without asking

# %%
# Asking user information

favorite_food = input("Enter your favorite food: ")
mood_today = input("How are you feeling today? ")
career_goal = input("What is your future career goal? ")

print("Favorite food:", favorite_food)
print("Mood today:", mood_today)
print("Career goal:", career_goal)

# %% [markdown]
# # Conceptual Task 4
#
# Incorrect data types problem

# %%
# Example of incorrect data type

balance = "5000"   # stored as string

deposit = 2000

# Correct conversion
balance = int(balance)

new_balance = balance + deposit

print("Updated balance:", new_balance)

# %% [markdown]
# # Conceptual Task 5
#
# Situations where numbers are not enough

# %%
# Example showing numbers and description

exam_score = 85
teacher_feedback = "Good understanding but needs more practice."

print("Exam score:", exam_score)
print("Teacher feedback:", teacher_feedback)
