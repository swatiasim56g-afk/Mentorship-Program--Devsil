# %%
# %time
# import libraries 
import tensorflow as tf
# %time
# import libraries 
import matplotlib.pyplot as plt          # ← fixed
from tensorflow.keras.datasets import mnist  # ← also correct the dataset name

# ignore warning
warnings.filterwarnings("ignore")

# load the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# define the simple model 
def create_model():
    model = Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model
from tensorflow.keras.datasets import mist
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# ignore warning
import warnings 
warnings.filterwarnings("ignore")

# load the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# define the simple model 
def create_model():
    model = Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    return model
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# CPU times: total: 0 ns
# Wall time: 0 ns
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 from tensorflow.keras.datasets import mnist  # ← also correct the dataset name
#       9 # ignore warning
# ---> 10 warnings.filterwarnings("ignore")
#      12 # load the dataset
#      13 (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
# NameError: name 'warnings' is not defined
