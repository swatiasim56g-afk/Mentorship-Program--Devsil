# %% [markdown]
# # Linear Regression

# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Import the tips dataset
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Now me make scatter plot of the bill and tip columns
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# split the data into x and y
x = tips[['total_bill']]
y = tips['tip']

# %%
# split the data into tain and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Now call and train the model 
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# take out model interscept slope and in equation

from pyexpat import model


print(model.intercept_)
print(model.coef_)
print('y=', model.intercept_, '+', model.coef_, '* x')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 6
#       1 # take out model interscept slope and in equation
#       3 from pyexpat import model
# ----> 6 print(model.intercept_)
#       7 print(model.coef_)
#       8 print('y=', model.intercept_, '+', model.coef_, '* x')
#
# AttributeError: module 'pyexpat.model' has no attribute 'intercept_'

# %%
# Predict
y_pred = model.predict(x_test)
