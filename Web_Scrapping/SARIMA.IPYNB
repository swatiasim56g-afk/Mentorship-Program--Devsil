# %%
# Import libraries
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# %%
# install the statsmodel library
# !pip install statsmodels
# Out:
# ...
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.6 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.6 MB 1.2 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.6 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.6 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.6 MB 1.3 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.6 MB 1.3 MB/s eta 0:00:06
# ...

# %%
import os

# load the dataset. we'll use the AirPassenger dataset 
# load the dataset. we'll use the AirPassenger dataset 

csv_file = "AirPassengers.csv"
if not os.path.isfile(csv_file):
    # the file isn’t in the working directory – either give the full
    # path or pull a copy from the web
    # csv_file = r"d:\Programming Practice\Mentorship Program @Devsil\Web_Scrapping\AirPassengers.csv"
    csv_file = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"

df = pd.read_csv(csv_file)

# Now we will use passenger column to tain out ARIMA model 
# for this example, we use an ARIMA(2, 1, 2) model.
model = SARIMAX(df['Passengers'], order=(2, 1, 2))
results = model.fit()
# make prediction 
predictions = results.forecast(steps=10)
print(predictions)
# plot the predictions
df['Passengers'].plot()
predictions.plot()
plt.show()

# Now we will use passenger column to tain out ARIMA model 
# for this example, we use an ARIMA(2, 1, 2) model.
model = SARIMAX(df['Passengers'], order=(2, 1, 2))
results = model.fit()
# make prediction 
predictions = model_fit.forcast(steps=10)
print(predictions)
# plot the predictions
df['Passengers'].plot()
predictions.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 17
#      13 df = pd.read_csv(csv_file)
#      15 # Now we will use passenger column to tain out ARIMA model
#      16 # for this example, we use an ARIMA(2, 1, 2) model.
# ---> 17 model = SARIMAX(df['Passengers'], order=(2, 1, 2))
#      18 results = model.fit()
#      19 # make prediction
#
# NameError: name 'SARIMAX' is not defined

# %%
# now the adf test

from statsmodels.tsa.stattools import adfuller
from numpy import log


def adf_test(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %% [markdown]
# # Time Series Forecasting of Stock Market Data with ARIMA IN Python

# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import yfinance as yf
import datetime as dt
from datetime import timedelta
import plotly.graph_objects as go
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
from datetime import date

# define the dates to fetch data
today = date.today()
d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=365)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2
print('your data will be fetched from {} to {}'.format(start_date, end_date))
# Out:
# your data will be fetched from 2025-03-07 to 2026-03-07

# %%
date.today
# Out:
# <function date.today>
