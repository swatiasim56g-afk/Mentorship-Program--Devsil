# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.2.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from yfinance) (3.0.1)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from yfinance) (4.5.0)
# Collecting pytz>=2022.5 (from yfinance)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-7.34.0-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting cffi>=1.12.0 (from curl_cffi<0.14,>=0.7->yfinance)
#   Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from requests>=2.31->yfinance) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Downloading yfinance-1.2.0-py2.py3-none-any.whl (130 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.8 MB/s  0:00:00
# Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl (182 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading peewee-4.0.1-py3-none-any.whl (139 kB)
# Using cached protobuf-7.34.0-cp310-abi3-win_amd64.whl (437 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading websockets-16.0-cp311-cp311-win_amd64.whl (178 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=16cd8b2f96af20192dc42ef6d05f5e1e4d4e5721ee660ef070156ca09897d357
#   Stored in directory: c:\users\muhammad asim\appdata\local\pip\cache\wheels\42\d6\84\bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# Successfully built multitasking
# Installing collected packages: pytz, peewee, multitasking, websockets, pycparser, protobuf, frozendict, cffi, curl_cffi, yfinance
#
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ---- -----------------------------------  1/10 [peewee]
#    -------- -------------------------------  2/10 [multitasking]
#    ------------ ---------------------------  3/10 [websockets]
#    ------------ ---------------------------  3/10 [websockets]
#    ---------------- -----------------------  4/10 [pycparser]
#    -------------------- -------------------  5/10 [protobuf]
#    -------------------- -------------------  5/10 [protobuf]
#    -------------------- -------------------  5/10 [protobuf]
#    ---------------------------- -----------  7/10 [cffi]
#    ---------------------------- -----------  7/10 [cffi]
#    -------------------------------- -------  8/10 [curl_cffi]
#    ------------------------------------ ---  9/10 [yfinance]
#    ------------------------------------ ---  9/10 [yfinance]
#    ---------------------------------------- 10/10 [yfinance]
#
# Successfully installed cffi-2.0.0 curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-4.0.1 protobuf-7.34.0 pycparser-3.0 pytz-2026.1.post1 websockets-16.0 yfinance-1.2.0

# %%
# import yfinance as yf and pandas as pd
import yfinance as yf
import pandas as pd
 # define ticker symbol 
tickerSymbol = 'AAPL'
# get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

# %%
# get the historical prices for this ticker
tickerDf = tickerData.history(start='2010-05-31', end='2020-05-31')
# last closing price
tickerDf['Close'].iloc[-1]
tickerDf.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-01 00:00:00-04:00  7.781093  7.968361  7.759219  7.815250  876472800
# 2010-06-02 00:00:00-04:00  7.926413  7.934204  7.800269  7.908736  688548000
# 2010-06-03 00:00:00-04:00  7.945587  7.956674  7.802664  7.883864  650106800
# 2010-06-04 00:00:00-04:00  7.736751  7.847314  7.629484  7.669334  758304400
# 2010-06-07 00:00:00-04:00  7.739146  7.764914  7.507232  7.518918  886942000
#
#                            Dividends  Stock Splits
# Date
# 2010-06-01 00:00:00-04:00        0.0           0.0
# 2010-06-02 00:00:00-04:00        0.0           0.0
# 2010-06-03 00:00:00-04:00        0.0           0.0
# 2010-06-04 00:00:00-04:00        0.0           0.0
# 2010-06-07 00:00:00-04:00        0.0           0.0

# %%
# print the shape
tickerDf.shape
# Out:
# (2517, 7)
