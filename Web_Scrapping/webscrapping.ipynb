# %%
# import libraris for web scrapping
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import requests
#       3 from bs4 import BeautifulSoup
# ----> 4 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.2-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.9 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 1.1 MB/s eta 0:00:08
#    ------- -------------------------------- 1.8/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.9 MB 1.1 MB/s eta 0:00:07
#    ----------- ---------------------------- 2.9/9.9 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.9/9.9 MB 1.2 MB/s eta 0:00:06
#    -------------- ------------------------- 3.7/9.9 MB 1.3 MB/s eta 0:00:05
#    --------------- ------------------------ 3.9/9.9 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.9 MB 1.4 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.9 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 5.0/9.9 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.9 MB 1.4 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.9 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.9 MB 1.5 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.9 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.1/9.9 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.9 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/9.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/9.9 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.5 MB/s  0:00:06
# Downloading numpy-2.4.2-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 672.2 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/12.6 MB 672.2 kB/s eta 0:00:18
#    --- ------------------------------------ 1.0/12.6 MB 949.8 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.6 MB 949.8 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.6 MB 959.4 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.6/12.6 MB 964.5 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/12.6 MB 1.0 MB/s eta 0:00:11
#    ------ --------------------------------- 2.1/12.6 MB 1.0 MB/s eta 0:00:11
#    ------- -------------------------------- 2.4/12.6 MB 1.0 MB/s eta 0:00:10
#    -------- ------------------------------- 2.6/12.6 MB 1.1 MB/s eta 0:00:10
#    --------- ------------------------------ 2.9/12.6 MB 1.1 MB/s eta 0:00:09
#    --------- ------------------------------ 3.1/12.6 MB 1.1 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.4/12.6 MB 1.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.6 MB 1.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.6 MB 1.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.6 MB 1.1 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.6 MB 1.0 MB/s eta 0:00:09
#    -------------- ------------------------- 4.5/12.6 MB 1.0 MB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.6 MB 1.0 MB/s eta 0:00:08
#    -------------- ------------------------- 4.7/12.6 MB 1.0 MB/s eta 0:00:08
#    --------------- ------------------------ 5.0/12.6 MB 1.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.2/12.6 MB 1.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.6 MB 1.0 MB/s eta 0:00:07
#    ------------------ --------------------- 5.8/12.6 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.0/12.6 MB 1.1 MB/s eta 0:00:07
#    ------------------- -------------------- 6.3/12.6 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.6 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 6.8/12.6 MB 1.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.6 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.6 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.6 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.6 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.9/12.6 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.6 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 8.1/12.6 MB 1.1 MB/s eta 0:00:05
#    --------------------------- ------------ 8.7/12.6 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.9/12.6 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.9/12.6 MB 1.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 9.4/12.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.6 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 10.2/12.6 MB 1.1 MB/s eta 0:00:03
#    --------------------------------- ------ 10.5/12.6 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.6 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.6 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.6 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 1.1 MB/s  0:00:11
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, numpy, pandas
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.4.2 pandas-3.0.1 tzdata-2025.3

# %%
# !pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.5-cp311-cp311-win_amd64.whl.metadata (39 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.5-cp311-cp311-win_amd64.whl (142 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    ------------------------ --------------- 3/5 [certifi]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# Successfully installed certifi-2026.2.25 charset_normalizer-3.4.5 idna-3.11 requests-2.32.5 urllib3-2.6.3

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Muhammad Asim\miniconda3\envs\web_scrapper\Lib\site-packages (from beautifulsoup4) (4.15.0)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# Successfully installed beautifulsoup4-4.14.3 soupsieve-2.8.3

# %%
# url 
url = "httlp://en.wikipedia.org/wiki/World_population"
response = requests.get(url)
 soup = BeautifulSoup(response.content, 'html.parser')

soup.title
soup.text
print(soup.title.text)

# %%
print(soup.prettify())

# %%
# find all the tables
tables = soup.find_all('table')
print(tables)

# %%
dataframe = []
for i, table in enumerate(tables):
    rows = table.find_all("tr")[1:]
    data = []
    for row in rows:
        cols = row.find_all("td")
        cols = [col.text.strip() for col in cols]
        data.append(cols)
    df = pd.DataFrame(data)
    dataframe.appned(df)
dataframe[0]
dataframe[1]
dataframe[2]
dataframe[3]
# Out:
# Running cells with 'Web_Scrap (Python 3.14.3)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n Web_Scrap ipykernel --update-deps --force-reinstall'

# %%
# save the table 
dataframe[1].to_csv("World_Population.csv", index=False, header=true)
