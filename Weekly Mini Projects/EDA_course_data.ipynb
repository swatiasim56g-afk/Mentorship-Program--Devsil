# %% [markdown]
# # Online course Analysis

# %% [markdown]
# ## import the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv(r"D:\Programming Practice\Mentorship Program @Devsil\Weekly Mini Projects\Week 2\week2_dataset.csv")

# %%
df
# Out:
#                   Course_Name      Category  Enrollments  Price  Rating  \
# 0        Python for Beginners   Programming         1200     50     4.5
# 1         Data Science Basics  Data Science          950     70     4.6
# 2      Machine Learning Intro            AI          800     90     4.7
# 3    Web Development Bootcamp           Web         1500     60     4.4
# 4       Digital Marketing 101     Marketing         1100     40     4.3
# 5             Advanced Python   Programming          600     80     4.6
# 6  Deep Learning Fundamentals            AI          450    120     4.8
# 7     Excel for Data Analysis  Data Science         1300     45     4.5
# 8             SQL Masterclass      Database          900     55     4.4
# 9         UI UX Design Basics        Design          700     50     4.2
#
#    Duration_Hours
# 0              40
# 1              45
# 2              50
# 3              55
# 4              30
# 5              35
# 6              60
# 7              25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Course_Name     10 non-null     object
#  1   Category        10 non-null     object
#  2   Enrollments     10 non-null     int64
#  3   Price           10 non-null     int64
#  4   Rating          10 non-null     float64
#  5   Duration_Hours  10 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 608.0+ bytes

# %%
df.shape
# Out:
# (10, 6)

# %% [markdown]
# ## checking null values

# %%
df.isnull().sum()
# Out:
# Course_Name       0
# Category          0
# Enrollments       0
# Price             0
# Rating            0
# Duration_Hours    0
# dtype: int64

# %% [markdown]
# ## Now checking duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#        Enrollments       Price     Rating  Duration_Hours
# count     10.00000   10.000000  10.000000       10.000000
# mean     950.00000   66.000000   4.500000       39.800000
# std      328.29526   24.698178   0.182574       12.218383
# min      450.00000   40.000000   4.200000       25.000000
# 25%      725.00000   50.000000   4.400000       30.000000
# 50%      925.00000   57.500000   4.500000       37.500000
# 75%     1175.00000   77.500000   4.600000       48.750000
# max     1500.00000  120.000000   4.800000       60.000000

# %%
df['Enrollments'].mean()
df['Enrollments'].max()
df['Enrollments'].min()
# Out:
# 450

# %% [markdown]
# ### Price Analysis

# %%
df['Price'].mean()
df['Price'].max()
df['Price'].min()
# Out:
# 40

# %% [markdown]
# ## identify trends

# %%
df.loc[df['Enrollments'].idxmax()]
# Out:
# Course_Name       Web Development Bootcamp
# Category                               Web
# Enrollments                           1500
# Price                                   60
# Rating                                 4.4
# Duration_Hours                          55
# Name: 3, dtype: object

# %%
df.loc[df['Enrollments'].idxmin()]
# Out:
# Course_Name       Deep Learning Fundamentals
# Category                                  AI
# Enrollments                              450
# Price                                    120
# Rating                                   4.8
# Duration_Hours                            60
# Name: 6, dtype: object

# %%
df.loc[df['Rating'].idxmax()]
# Out:
# Course_Name       Deep Learning Fundamentals
# Category                                  AI
# Enrollments                              450
# Price                                    120
# Rating                                   4.8
# Duration_Hours                            60
# Name: 6, dtype: object

# %%
df.groupby('Category')['Enrollments'].mean()
# Out:
# Category
# AI               625.0
# Data Science    1125.0
# Database         900.0
# Design           700.0
# Marketing       1100.0
# Programming      900.0
# Web             1500.0
# Name: Enrollments, dtype: float64

# %% [markdown]
# ## visualization

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(df['Course_Name'], df['Enrollments'])
plt.xticks(rotation=90)
plt.xlabel("Course Name")
plt.ylabel("Enrollments")
plt.title("Online Course Enrollments")
plt.show()
