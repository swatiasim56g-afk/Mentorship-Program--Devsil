# %% [markdown]
# # Netflix Movies & TV Shows – EDA Storytelling
#
# ## Objective
# The purpose of this project is to perform Exploratory Data Analysis (EDA) on the Netflix dataset
# to understand content trends, types, and distribution using Markdown storytelling.

# %% [markdown]
# ## load the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Read the Dataset

# %%
df = pd.read_csv(r"D:\Programming Practice\Mentorship Program @Devsil\Weekly Mini Projects\Week 1\Netflix.csv")

# %% [markdown]
# ## Understand the Dataset

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.sample(6)
# Out:
#      show_id     type                  title        director  \
# 3245   s3246  TV Show       Singapore Social             NaN
# 8281   s8282    Movie           The Drowning    Bette Gordon
# 1176   s1177    Movie  Any Crybabies Around?     Takuma Sato
# 1231   s1232  TV Show         City of Ghosts             NaN
# 5589   s5590    Movie    Operações Especiais  Tomas Portella
# 1569   s1570  TV Show      Masameer Classics             NaN
#
#                                                    cast  \
# 3245  Nicole Ong, Mae Tan, Sukki Singapora, Vinny Sh...
# 8281  Josh Charles, Julia Stiles, Avan Jogia, Tracie...
# 1176  Taiga Nakano, Riho Yoshioka, Kanichiro, Takash...
# 1231  August Nuñez, Blue Chapman, Kirikou S'hai Muld...
# 5589  Cleo Pires, Marcos Caruso, Thiago Martins, Fab...
# 1569                    Malik Nejer, Abdulaziz Alshehri
#
#                        country         date_added  release_year rating  \
# 3245  Singapore, United States  November 22, 2019          2019  TV-MA
# 8281  United States, Hong Kong  September 1, 2017          2016  TV-MA
# 1176                     Japan     March 20, 2021          2020  TV-MA
# 1231             United States      March 5, 2021          2021  TV-Y7
# 5589                    Brazil  February 25, 2017          2015  TV-MA
# 1569              Saudi Arabia   December 9, 2020          2013  TV-14
#
#        duration                                 listed_in  \
# 3245   1 Season        International TV Shows, Reality TV
# 8281     99 min                                 Thrillers
# 1176    108 min              Dramas, International Movies
# 1231   1 Season                                  Kids' TV
# 5589     99 min  Action & Adventure, International Movies
# 1569  4 Seasons       International TV Shows, TV Comedies
#
#                                             description
# 3245  Peer into the lives of young Singaporeans as t...
# 8281  Child psychologist Tom Seymour's testimony hel...
# 1176  An immature young father in Akita becomes an o...
# 1231  Meet the Ghost Club! Their adventures take the...
# 5589  In a crime-plagued area of Rio de Janeiro, a t...
# 1569  Through dark comedy and eccentric characters, ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Percentage of null values

# %%
Total_values = df.shape[0]
null_values = df['director'].isnull().sum()
percentages = (null_values / Total_values) * 100
percentages
# Out:
# 29.908027705234474

# %% [markdown]
# # Now Data Cleaning

# %%
df['director'].fillna('Unknown', inplace=True)

# %% [markdown]
# #### now we check it's working

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %%
df['country'].fillna('Unknown', inplace=True)
df['rating'].fillna('Not Rated', inplace=True)
df['cast'].fillna('Not Available', inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df['date_added'].fillna('September 9, 2019', inplace=True)
df['duration'].fillna('90 min', inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### convert the date_added into date and time

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8719 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df['release_year'] = df['release_year'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8719 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# ## Removing Duplicates rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### we have no any duplicates in the Netflix dataset

# %% [markdown]
# ### clean the text

# %%
df['country'] = df['country'].str.strip()

# %% [markdown]
# ## Data Cleaning
#
# The dataset contained missing values in columns such as director, country, rating, and cast.
# These missing values were filled with meaningful placeholders to avoid data loss.
#
# Data types were checked and corrected where necessary.
# Duplicate rows were removed to ensure data accuracy.
# Text values were cleaned by removing extra spaces.
